# %%
import pandas as pd

# %%
 df1 = pd.read_excel('Gapminder_key_1.xlsx')

# %%
df1.head()
# Out:
#        country  year  population continent
# 0  Afghanistan  1952     8425333      Asia
# 1  Afghanistan  1957     9240934      Asia
# 2  Afghanistan  1962    10267083      Asia
# 3  Afghanistan  1967    11537966      Asia
# 4  Afghanistan  1972    13079460      Asia

# %%
df2 = pd.read_excel('Gapminder_key_2.xlsx')

# %%
df2.head()
# Out:
#        country  year  life_exp     gdp_cap
# 0  Afghanistan  1952    28.801  779.445314
# 1  Afghanistan  1957    30.332  820.853030
# 2  Afghanistan  1962    31.997  853.100710
# 3  Afghanistan  1967    34.020  836.197138
# 4  Afghanistan  1972    36.088  739.981106

# %%
df1.info
# Out:
# <bound method DataFrame.info of           country  year  population continent
# 0     Afghanistan  1952     8425333      Asia
# 1     Afghanistan  1957     9240934      Asia
# 2     Afghanistan  1962    10267083      Asia
# 3     Afghanistan  1967    11537966      Asia
# 4     Afghanistan  1972    13079460      Asia
# ...           ...   ...         ...       ...
# 1699     Zimbabwe  1987     9216418    Africa
# 1700     Zimbabwe  1992    10704340    Africa
# 1701     Zimbabwe  1997    11404948    Africa
# 1702     Zimbabwe  2002    11926563    Africa
# 1703     Zimbabwe  2007    12311143    Africa
#
# [1704 rows x 4 columns]>

# %%
df2.info
# Out:
# <bound method DataFrame.info of           country  year  life_exp     gdp_cap
# 0     Afghanistan  1952    28.801  779.445314
# 1     Afghanistan  1957    30.332  820.853030
# 2     Afghanistan  1962    31.997  853.100710
# 3     Afghanistan  1967    34.020  836.197138
# 4     Afghanistan  1972    36.088  739.981106
# ...           ...   ...       ...         ...
# 1699     Zimbabwe  1987    62.351  706.157306
# 1700     Zimbabwe  1992    60.377  693.420786
# 1701     Zimbabwe  1997    46.809  792.449960
# 1702     Zimbabwe  2002    39.989  672.038623
# 1703     Zimbabwe  2007    43.487  469.709298
#
# [1704 rows x 4 columns]>

# %%
len(df1)
# Out:
# 1704

# %%
len(df2)
# Out:
# 1704

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of           country  year  population continent
# 0     Afghanistan  1952     8425333      Asia
# 1     Afghanistan  1957     9240934      Asia
# 2     Afghanistan  1962    10267083      Asia
# 3     Afghanistan  1967    11537966      Asia
# 4     Afghanistan  1972    13079460      Asia
# ...           ...   ...         ...       ...
# 1699     Zimbabwe  1987     9216418    Africa
# 1700     Zimbabwe  1992    10704340    Africa
# 1701     Zimbabwe  1997    11404948    Africa
# 1702     Zimbabwe  2002    11926563    Africa
# 1703     Zimbabwe  2007    12311143    Africa
#
# [1704 rows x 4 columns]>

# %%
frames =[df1,df2]
result = pd.concat(frames)

# %%
result
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952   8425333.0      Asia       NaN         NaN
# 1     Afghanistan  1957   9240934.0      Asia       NaN         NaN
# 2     Afghanistan  1962  10267083.0      Asia       NaN         NaN
# 3     Afghanistan  1967  11537966.0      Asia       NaN         NaN
# 4     Afghanistan  1972  13079460.0      Asia       NaN         NaN
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987         NaN       NaN    62.351  706.157306
# 1700     Zimbabwe  1992         NaN       NaN    60.377  693.420786
# 1701     Zimbabwe  1997         NaN       NaN    46.809  792.449960
# 1702     Zimbabwe  2002         NaN       NaN    39.989  672.038623
# 1703     Zimbabwe  2007         NaN       NaN    43.487  469.709298
#
# [3408 rows x 6 columns]

# %%
result1 = pd.merge(df1, df2, on=["country", "year"])

# %%
result1
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
result1.gdp_cap.std()
# Out:
# 9857.454542541445

# %%
result1.gdp_cap.mean()
# Out:
# 7215.327081212142

# %%
result1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 93.2+ KB

# %%
df4 = result1.astype({"country":'category', "continent":'category'})

# %%
df4
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   category
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   category
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: category(2), float64(2), int64(2)
# memory usage: 76.9 KB

# %%
rslt_df = df4.sort_values(by = 'gdp_cap',ascending = False)

# %%
rslt_df.tail()
# Out:
#               country  year  population continent  life_exp     gdp_cap
# 333  Congo, Dem. Rep.  1997    47798986    Africa    42.587  312.188423
# 624     Guinea-Bissau  1952      580653    Africa    32.500  299.850319
# 876           Lesotho  1952      748747    Africa    42.138  298.846212
# 335  Congo, Dem. Rep.  2007    64606759    Africa    46.462  277.551859
# 334  Congo, Dem. Rep.  2002    55379852    Africa    44.966  241.165876

# %%
df4['GDP'] = df4['gdp_cap'] * df4['population']

# %% [markdown]
# df4.GDP.max

# %%
import matplotlib.pyplot as plt

# %%
df4.plot(x="year", y="life_exp", kind="bar")
plt.show()

# %%
plt.show()

# %%
df4.corr()
# Out:
#                 year  population  life_exp   gdp_cap       GDP
# year        1.000000    0.082308  0.435611  0.227318  0.149633
# population  0.082308    1.000000  0.064955 -0.025600  0.430734
# life_exp    0.435611    0.064955  1.000000  0.583706  0.258367
# gdp_cap     0.227318   -0.025600  0.583706  1.000000  0.315484
# GDP         0.149633    0.430734  0.258367  0.315484  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(40,20))
sns.set(font_scale=3)
sns.swarmplot(data = df4, x = "country", y = "life_exp", dodge = True)
plt.show()
# Out:
# C:\Users\Mohit\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df4.India
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11964/1962233517.py in <module>
# ----> 1 df4.India
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'India'

# %%
import re

s = 'VarunRao: A Data Scientist'

match = re.search(r'Data', s)

print('Start Index:', match.start())
print('End Index:', match.end())
# Out:
# Start Index: 12
# End Index: 16
